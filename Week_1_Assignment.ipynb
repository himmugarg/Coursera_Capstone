# %% [markdown]
# ## This notebook the IBM Data Science Capstone Course. This is week 1

# %%
import pandas as pd
import numpy as np

# %%
print ("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
